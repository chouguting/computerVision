# %%
import matplotlib.pyplot as plt

print('hello world')
# Out:
# hello world

# %%
plt.imread('hw1/part1/testdata/1.png')
# Out:
# array([[[0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039],
#         ...,
#         [0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039]],
#
#        [[0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039],
#         ...,
#         [0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039]],
#
#        [[0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039],
#         ...,
#         [0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039]],
#
#        ...,
#
#        [[0.6745098, 0.8352941, 0.9098039],
#         [0.6745098, 0.8352941, 0.9098039],
# ...
